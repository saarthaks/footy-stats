# %%
import numpy as np
import pandas as pd

# %%
cols = ['Rk', 'Player', 'Pos', 'Squad']
df_basic = pd.read_csv('./data/standard_stats.csv', skiprows=1, usecols=cols)

cols = ['Min', 'Gls', 'Ast', 'xG', 'npxG', 'xA']
df_stand = pd.read_csv('./data/standard_stats.csv', skiprows=1, usecols=cols)
for c in cols[1:]:
    df_stand[c] = df_stand[c] / df_stand['Min'] * 90
print(df_stand.columns)
    
cols = ['Sh', 'SoT', 'FK']
df_shoot = pd.read_csv('./data/shooting_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_shoot[c] = df_shoot[c] / df_stand['Min'] * 90
print(df_shoot.columns)

cols = ['Cmp', 'Att', 'TotDist', 'PrgDist', 'Cmp.1', 'Att.1', 'Cmp.2', 'Att.2', 
        'Cmp.3', 'Att.3', 'KP', '1/3', 'PPA', 'CrsPA', 'Prog']
df_pass = pd.read_csv('./data/passing_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_pass[c] = df_pass[c] / df_stand['Min'] * 90
new_cols = {'Cmp': 'PassCmp', 'Att': 'PassAttm', 'TotDist': 'TotalPassDist', 
            'PrgDist': 'PrgPassDist', 'Cmp.1': 'ShortCmp', 'Att.1': 'ShortAttm', 
            'Cmp.2': 'MedCmp', 'Att.2': 'MedAttm', 'Cmp.3': 'LongCmp', 'Att.3': 'LongAttm',
            'KP': 'KeyPasses', '1/3': 'FinalThirdPass', 'PPA': 'PenPass', 'Prog': 'PrgPassNum'}
df_pass = df_pass.rename(columns=new_cols,)
print(df_pass.columns)

cols = ['Live', 'Dead', 'TB' ,'Press', 'Sw', 'Crs', 'Ground', 'Low', 'High', 'Int']
df_passtype = pd.read_csv('./data/pass_types_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_passtype[c] = df_passtype[c] / df_stand['Min'] * 90
new_cols = {'TB': 'ThroughBalls', 'Press': 'PassUnderPress', 'Sw': 'SwitchingPass',
            'Int': 'InterceptedPass'}
df_passtype = df_passtype.rename(columns=new_cols)
print(df_passtype.columns)

cols = ['SCA', 'GCA']
df_goalshot = pd.read_csv('./data/goal_shot_creation_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_goalshot[c] = df_goalshot[c] / df_stand['Min'] * 90
print(df_goalshot.columns)

cols = ['Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Tkl.1', 'Att', 'Press', 'Succ',
        'Def 3rd.1', 'Mid 3rd.1', 'Att 3rd.1', 'Blocks', 'Sh', 'Pass', 'Int', 'Clr']
df_def = pd.read_csv('./data/defensive_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_def[c] = df_def[c] / df_stand['Min'] * 90
new_cols = {'Def 3rd': 'TklDef3rd', 'Mid 3rd': 'TklMid3rd', 'Att 3rd': 'TklAtt3rd',
            'Tkl.1': 'DribTkl', 'Att': 'DribTklAttm', 'Press': 'NumPressed', 'Succ': 'SuccPress', 
            'Def 3rd.1': 'PressDef3rd', 'Mid 3rd.1': 'PressMid3rd', 'Att 3rd.1': 'PressAtt3rd',
            'Sh': 'ShotsBlocked', 'Pass': 'PassesBlocked', 'Int': 'PassesIntercepted'}
df_def = df_def.rename(columns=new_cols)
print(df_def.columns)
    
cols = ['Def Pen', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att Pen', 'Live', 'Succ', 'Att', 
        '#Pl', 'Megs', 'Carries', 'TotDist', 'PrgDist', 'Targ', 'Rec', 'Miscon', 'Dispos']
df_poss = pd.read_csv('./data/possession_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_poss[c] = df_poss[c] / df_stand['Min'] * 90
new_cols = {'Def Pen': 'TouchesDefPen', 'Def 3rd': 'TouchesDef3rd', 'Mid 3rd': 'TouchesMid3rd', 
            'Att 3rd': 'TouchesAtt3rd', 'Att Pen': 'TouchesAttPen', 'Live': 'LiveTouches', 
            'Succ': 'SuccDrib', 'Att': 'AttmDrib', '#Pl': 'PlayersDrib', 'TotDist': 'DistCarried',
            'PrgDist': 'PrgDistCarried', 'Targ': 'TargetOfPass', 'Rec': 'PassesRec'}
df_poss = df_poss.rename(columns=new_cols)
print(df_poss.columns)

cols = ['Fls', 'Recov', 'Won', 'Lost']
df_misc = pd.read_csv('./data/misc_stats.csv', skiprows=1, usecols=cols)
for c in cols:
    df_misc[c] = df_misc[c] / df_stand['Min'] * 90
new_cols = {'Fls': 'Fouls', 'Recov': 'LooseBallsRecov', 'Won': 'AerialsWon', 'Lost': 'AerialsLost'}
df_misc = df_misc.rename(columns=new_cols)
print(df_misc.columns)
# Out:
# Index(['Min', 'Gls', 'Ast', 'xG', 'npxG', 'xA'], dtype='object')
# Index(['Sh', 'SoT', 'FK'], dtype='object')
# Index(['PassCmp', 'PassAttm', 'TotalPassDist', 'PrgPassDist', 'ShortCmp',
#        'ShortAttm', 'MedCmp', 'MedAttm', 'LongCmp', 'LongAttm', 'KeyPasses',
#        'FinalThirdPass', 'PenPass', 'CrsPA', 'PrgPassNum'],
#       dtype='object')
# Index(['Live', 'Dead', 'ThroughBalls', 'PassUnderPress', 'SwitchingPass',
#        'Crs', 'Ground', 'Low', 'High', 'InterceptedPass'],
#       dtype='object')
# Index(['SCA', 'GCA'], dtype='object')
# Index(['Tkl', 'TklW', 'TklDef3rd', 'TklMid3rd', 'TklAtt3rd', 'DribTkl',
#        'DribTklAttm', 'NumPressed', 'SuccPress', 'PressDef3rd', 'PressMid3rd',
#        'PressAtt3rd', 'Blocks', 'ShotsBlocked', 'PassesBlocked',
#        'PassesIntercepted', 'Clr'],
#       dtype='object')
# Index(['TouchesDefPen', 'TouchesDef3rd', 'TouchesMid3rd', 'TouchesAtt3rd',
#        'TouchesAttPen', 'LiveTouches', 'SuccDrib', 'AttmDrib', 'PlayersDrib',
#        'Megs', 'Carries', 'DistCarried', 'PrgDistCarried', 'TargetOfPass',
#        'PassesRec', 'Miscon', 'Dispos'],
#       dtype='object')
# Index(['Fouls', 'LooseBallsRecov', 'AerialsWon', 'AerialsLost'], dtype='object')

# %%
df = pd.concat([df_stand, df_shoot, df_pass, df_passtype, df_goalshot, df_def, df_poss, df_misc], axis=1)
df2 = df.fillna(0)

player_data = df2.values
remove_idx = np.where(player_data[:,0] < 90)[0]
df3 = df2.drop(list(remove_idx))
df_basic = df_basic.drop(list(remove_idx))
player_data = df3.values

print(player_data.shape)
# Out:
# (471, 74)

# %%
def player_mapping(ranking, name):
    rk2idx = {}
    idx2rk = {}
    for i, d in enumerate(ranking):
        rk2idx[d] = i
        idx2rk[i] = d
    
    name2idx = {}
    idx2name = {}
    for i, d in enumerate(name):
        nm = d[d.index('\\')+1:]
        name2idx[nm] = i
        idx2name[i] = nm
    
    return rk2idx, idx2rk, name2idx, idx2name

rk2idx, idx2rk, name2idx, idx2name = player_mapping(df_basic['Rk'], df_basic['Player'])

# %%
from sklearn.decomposition import PCA, SparsePCA
import matplotlib.pyplot as plt

# %%
def similar_players(name, data):
    idx = name2idx[name]
    player = data[idx,:]
    player_norm = np.linalg.norm(player)
    data_norm = np.linalg.norm(data, axis=1)
    scores = data @ player / data_norm / player_norm
    
    sorted_scores = -np.sort(-scores)[1:]
    ranked_idx = np.argsort(-scores)[1:]
    names = [idx2name[idx] for idx in ranked_idx]
        
    return names, sorted_scores

# %%
pca = SparsePCA(n_components=15)
pca.fit(player_data[:, 1:])
# Out:
# SparsePCA(U_init=None, V_init=None, alpha=1, max_iter=1000, method='lars',
#      n_components=15, n_jobs=1, random_state=None, ridge_alpha=0.01,
#      tol=1e-08, verbose=False)

# %%
player_trans2 = pca.transform(player_data[:, 1:])

# %%
names, scores = similar_players('Pierre-Emerick-Aubameyang', player_trans2)
for name, score in zip(names, scores):
    print(name, score)
# Out:
# Anwar-El-Ghazi 0.9639171173868594
# Andriy-Yarmolenko 0.9600285113573892
# Harvey-Barnes 0.9491618182209468
# Sadio-Mane 0.9442863479303533
# Divock-Origi 0.9424531724235946
# Theo-Walcott 0.9372474360200977
# Billy-Sharp 0.9365528035117001
# Michail-Antonio 0.9364180069940916
# Roberto-Firmino 0.9278644289588384
# Mohamed-Salah 0.9244871618177714
# Richarlison 0.9155845341917297
# Ismaila-Sarr 0.9139760982326628
# Marcus-Rashford 0.9136837558019657
# Trezeguet 0.9124253118845526
# Ayoze-Perez 0.9106861898648771
# Danny-Welbeck 0.9090869710262256
# Kelechi-Iheanacho 0.9046275769129161
# Danny-Ings 0.9045866782423674
# Christian-Pulisic 0.9040983561447233
# Son-Heung-min 0.901731941599516
# Sergio-Aguero 0.9014345542382097
# Leandro-Trossard 0.9012505620567459
# Marco-Stiepermann 0.9012330045031417
# Roberto-Pereyra 0.8980535399272417
# Morgan-Gibbs-White 0.897233947319147
# Callum-Wilson 0.8958853130296972
# Anthony-Martial 0.8922699396205438
# David-McGoldrick 0.8910441879210069
# Callum-Robinson 0.8873947818636796
# David-Brooks 0.8867134112379806
# Andre-Gray 0.8858276935249979
# Daniel-Podence 0.8831410188334348
# Callum-Hudson-Odoi 0.8828540143180826
# Daniel-James 0.8827973649439131
# Neal-Maupay 0.8811977187997437
# Steven-Bergwijn 0.8809208502760976
# Joshua-King 0.8808533478318097
# Ibrahim-Amadou 0.19524950213607334
# Ben-Foster 0.1899138489439193
# Orjan-Nyland 0.18862548374395544
# Wes-Morgan 0.18806138944213566
# Alex-McCarthy 0.17718271719837578
# Nick-Pope 0.17468023568456031
# Nabil-Bentaleb 0.1733670350304945
# Lukasz-Fabianski 0.17233679930966975
# Willy-Caballero 0.17198571349476455
# Angus-Gunn 0.17020915765355304
# Jordan-Pickford 0.16961368925413922
# Mathew-Ryan 0.15951208031062472
# Pepe-Reina 0.1554254519064607
# Roberto 0.15461321480530227
# Phil-Jagielka 0.1538222983897062
# Tim-Krul 0.15204490207843027
# Jan-Bednarek 0.15143855386707686
# Martin-Dubravka 0.1458091447096134
# Claudio-Bravo 0.14526688649068614
# Vicente-Guaita 0.14268784810126459
# Darren-Randolph 0.14065520707288875
# Aaron-Ramsdale 0.13974508317775802
# David-Martin 0.13722464237576204
# Virgil-van-Dijk 0.13416111657513738
# Simon-Moore 0.13377568575572682
# Wayne-Hennessey 0.1264928300008148
# Carlos-Sanchez 0.11448203311203284
# Kasper-Schmeichel 0.11325292407744318
# Mark-Travers 0.1105411740729611
# Tom-Heaton 0.10752441977134158
# Adrian 0.1066302826232617
# Rui-Patricio 0.1050510373618507
# Ederson 0.10183653646442792
# Eric-Garcia 0.10107790122217195
# Paulo-Gazzaniga 0.09564956668534892
# Alisson 0.09534981980665731
# Kepa-Arrizabalaga 0.09270507918162992
# Hugo-Lloris 0.0891061367200373
# Michael-McGovern 0.06151943369627923
# Emiliano-Martinez 0.05586657351278902
# David-de-Gea 0.04980311971323051
# Bernd-Leno 0.0376362962978853

# %%
pca2 = PCA(n_components=15, whiten=True)
pca2.fit(player_data[:, 1:])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=15, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=True)

# %%
plt.figure(figsize=(8,6))
plt.semilogy(pca2.explained_variance_ratio_, '--.')

# %%
player_trans = pca2.transform(player_data[:, 1:])

# %%
names, scores = similar_players('Richarlison', player_trans)

# %%
for name, score in zip(names, scores):
    print(name, score)
# Out:
# Joshua-King 0.8581707815796845
# Lucas-Moura 0.7896030111656971
# Michail-Antonio 0.7578681283105931
# Divock-Origi 0.738795180978804
# Sofiane-Boufal 0.724804468724999
# Christian-Pulisic 0.7114908246983441
# Moussa-Djenepo 0.7002998996181881
# Ismaila-Sarr 0.6948717200677582
# Nathan-Redmond 0.6679962863695993
# Wilfried-Zaha 0.6672418447072196
# Danny-Ings 0.625185768530808
# Moise-Kean 0.5663976250019566
# Michael-Obafemi 0.5569599352310451
# Stuart-Armstrong 0.5486537981559975
# Roberto-Pereyra 0.547156605867111
# Che-Adams 0.5437048408110712
# Trezeguet 0.54220099430919
# Sadio-Mane 0.5411332363744951
# Lys-Mousset 0.5383608797028038
# Joe-Willock 0.5226130229914372
# Adama-Traore 0.5179543314606267
# Martinelli 0.49706401972012826
# Dele-Alli 0.4968450781223542
# Allan-Saint-Maximin 0.49625175586151704
# Onel-Hernandez 0.4856972585908927
# Kelechi-Iheanacho 0.4843975710497246
# Raul-Jimenez 0.4822658352546016
# Daniel-Podence 0.4765413778132068
# Jamaal-Lascelles -0.0626131277462562
# Sam-Byram -0.06455742598047595
# Davy-Propper -0.06572661552393705
# Bukayo-Saka -0.06693245357076606
# Oriol-Romeu -0.07106940498915446
# Antonio-Rudiger -0.07231993835951578
# Paul-Dummett -0.07274022390811459
# Wilfred-Ndidi -0.07309252371407587
# John-Lundstram -0.07364321712163453
# David-Luiz -0.07374997319722594
# Willy-Caballero -0.07449495276205072
# Kevin-Long -0.07652379036113169
# Declan-Rice -0.08013883898829147
# Mateo-Kovacic -0.08079297432172994
# Matthew-Lowton -0.08899473788633713
# James-Maddison -0.08990240198289787
# Marcos-Alonso -0.10194427946842995
# Adam-Smith -0.10670556673262188
# Jesse-Lingard -0.108838816870674
# Gary-Cahill -0.10932927838429946
# Rui-Patricio -0.11057565664835955
# Jack-Stacey -0.11132510139866103
# Erik-Pieters -0.11379427108779079
# Diego-Rico -0.11682854750279134
# Djibril-Sidibe -0.11874583307796625
# Robert-Snodgrass -0.11985262444259703
# Mathew-Ryan -0.12025120219663238
# Enda-Stevens -0.12134612012202502
# Ryan-Fraser -0.1213664024083678
# Orjan-Nyland -0.12212734097462496
# Jetro-Willems -0.12412895674691272
# Jonny-Evans -0.12634213310431205
# Rob-Holding -0.12759285951030586
# Tim-Krul -0.1285952165040248
# Kenny-McLean -0.12880895836659642
# Morgan-Schneiderlin -0.12923675295865752
# Aaron-Ramsdale -0.13034686941410137
# Grant-Hanley -0.13121795165381275
# Marcos-Rojo -0.1328725269495859
# Jonny-Castro -0.133814761455139
# Danny-Drinkwater -0.13419803758771306
# Jack-Simpson -0.13650519890895657
# Alexis-Mac-Allister -0.13683871433344844
# Virgil-van-Dijk -0.13736300831296575
# Ben-Osborn -0.14118445667306004
# Ben-Chilwell -0.14137049408804728
# Phil-Bardsley -0.14222616611009575
# Kurt-Zouma -0.14285210082254712
# Nathan-Ake -0.1439163403270307
# Lucas-Torreira -0.14469908011319013
# Javier-Hernandez -0.1489497843091311
# Tom-Heaton -0.14903709851218164
# Jordan-Henderson -0.14907699674397593
# Fikayo-Tomori -0.15046717157596345
# Hugo-Lloris -0.15065467276511554
# Danny-Rose -0.15138408024751568
# Tom-Trybull -0.15349473982539308
# Calum-Chambers -0.1541859755384379
# Matt-Doherty -0.15458610826222668
# Manuel-Lanzini -0.1558937605980862
# Trent-Alexander-Arnold -0.1560737499285505
# Lewis-Dunk -0.15659644132624176
# Isaac-Hayden -0.15669321124172184
# Aymeric-Laporte -0.15694547550265883
# Sean-Longstaff -0.15781625706391206
# Toby-Alderweireld -0.15844527778655332
# Axel-Tuanzebe -0.1586784797085527
# Max-Aarons -0.16010703452739808
# Serge-Aurier -0.16013457543269094
# Xherdan-Shaqiri -0.1605422671205636
# Fabian-Delph -0.16080581746478012
# Jonjo-Shelvey -0.1615717121212849
# Georginio-Wijnaldum -0.16392274019104816
# James-McCarthy -0.16754696570351582
# Joao-Cancelo -0.16997095118398503
# Tom-Cleverley -0.17355751321360466
# Caglar-Soyuncu -0.17363683534983426
# Joe-Gomez -0.17490702593781907
# George-Baldock -0.1763820995636606
# Simon-Moore -0.17938465175174334
# John-Stones -0.18109786639490055
# Mark-Travers -0.18275870465827806
# Dan-Burn -0.1839957377744024
# Bruno-Fernandes -0.18409396938424527
# Jamal-Lewis -0.1861147631693925
# Mark-Noble -0.19495388181343962
# Lucas-Digne -0.19986777095220612
# John-Fleck -0.20073058071752933
# Cedric-Soares -0.2024664210253867
# Marvelous-Nakamba -0.20349120891703137
# Ryan-Bennett -0.20468690219500016
# Nemanja-Matic -0.20803133333993465
# Ibrahim-Amadou -0.20915640247113404
# Dani-Ceballos -0.20923039485683448
# Angus-Gunn -0.20924452250805617
# Maya-Yoshida -0.21028771469005084
# Valentino-Lazaro -0.21105977068468693
# Mamadou-Sakho -0.21691820505860138
# Daryl-Janmaat -0.2175331531043271
# Ben-Godfrey -0.21798855160062902
# Jorginho -0.2184668240823926
# Martin-Montoya -0.21882846553351193
# Eric-Dier -0.21920141415066133
# David-Silva -0.2216459179727567
# Ryan-Fredericks -0.22462745059403946
# Alisson -0.22612840883027732
# Nampalys-Mendy -0.22636709131654292
# Pascal-Gross -0.2283973650074064
# Ki-Sung-yueng -0.23125988333851968
# Gylfi-Sigurdsson -0.23137388657799374
# Josh-Brownhill -0.2319460467844866
# Aaron-Wan-Bissaka -0.2322283906524804
# Ben-Johnson -0.23245686053484818
# Tyrick-Mitchell -0.2335663687268987
# Ryan-Sessegnon -0.2346541233369817
# Adrian -0.23479671033475918
# Rodri -0.23955498334490827
# Dale-Stephens -0.2416736348302698
# Martin-Kelly -0.24201039970344104
# Nicolas-Otamendi -0.24360023357718924
# Youri-Tielemans -0.24367413495900364
# Michael-McGovern -0.2449457452211817
# Ederson -0.24736231491040464
# Ahmed-Elmohamady -0.25004187745525064
# Kasper-Schmeichel -0.25290271922691865
# Davinson-Sanchez -0.2534358483069889
# Matt-Ritchie -0.2550591439789616
# Sokratis-Papastathopoulos -0.25807276857786926
# Paulo-Gazzaniga -0.25889859222307166
# Jarrad-Branthwaite -0.26568035714453453
# DeAndre-Yedlin -0.26607819774020436
# Andreas-Christensen -0.26973689214825947
# Granit-Xhaka -0.27001289196263045
# Jairo-Riedewald -0.27139215372319714
# Fabinho -0.2714403241191556
# Oliver-Norwood -0.2717412537282902
# Lloyd-Kelly -0.2723108589978327
# William-Smallbone -0.2736600777550115
# Leander-Dendoncker -0.2739111132275842
# Ruben-Loftus-Cheek -0.274090281282543
# Charlie-Daniels -0.27446747765091967
# Joao-Moutinho -0.27530593029455647
# Reece-James -0.27556181658883067
# Nacho-Monreal -0.27587452923680794
# Hamza-Choudhury -0.27723534631552615
# Kyle-Walker-Peters -0.2817521935543702
# Pablo-Zabaleta -0.2821648359950964
# Angelino -0.28479966755173597
# Moussa-Sissoko -0.28705766254975584
# Juan-Mata -0.28749090262324833
# Cesar-Azpilicueta -0.2881766037450738
# Emerson-Palmieri -0.2921894238414402
# James-Ward-Prowse -0.29736887332509704
# Ezri-Konsa -0.2975798225524919
# Ryan-Bertrand -0.2978212834307814
# Brandon-Williams -0.2984944709270451
# Hector-Bellerin -0.2985509501738201
# Bernd-Leno -0.299310985348355
# Adrian-Mariappa -0.2995221804616128
# Luke-Shaw -0.30401616821118954
# Wes-Morgan -0.3053263697845573
# Claudio-Bravo -0.3063371436027532
# Kepa-Arrizabalaga -0.30714834161406646
# Moritz-Leitner -0.3080429314664304
# Eric-Garcia -0.31042222173452033
# Emiliano-Martinez -0.31649698739080667
# James-Justin -0.3166983193459571
# Christian-Eriksen -0.31843022100703555
# Matt-Targett -0.318704808291713
# Joel-Ward -0.3214955694969015
# Aaron-Cresswell -0.32346925872234394
# Andrew-Surman -0.33018890178089455
# Christian-Fuchs -0.3344980246014654
# Victor-Lindelof -0.33524069082201746
# Javier-Manquillo -0.3435127365175083
# Alexander-Tettey -0.3442834386252846
# Emil-Krafth -0.34495943100652354
# Ainsley-Maitland-Niles -0.3476565596847466
# Ashley-Westwood -0.34803826574174257
# Jose-Holebas -0.3494234725900794
# Danny-Rose -0.3496375122735636
# Kyle-Walker -0.34997779376030286
# Nabil-Bentaleb -0.3529851303056678
# Andrew-Robertson -0.3580044013084347
# Mesut-Ozil -0.3632567700740766
# Kieran-Tierney -0.36652546378529854
# Ondrej-Duda -0.3728673394194072
# Ashley-Young -0.3747546125066319
# Jan-Vertonghen -0.37729749331734486
# Timm-Klose -0.38546306372831435
# Matthew-Longstaff -0.3896394535579654
# David-de-Gea -0.3903582558772417
# Patrick-van-Aanholt -0.39955338417014397
# Ben-Davies -0.4045897917868326
# Cedric-Soares -0.40676222735736767
# Luka-Milivojevic -0.4301141159800383
# Kiko-Femenia -0.4403105913269303
# Benjamin-Mendy -0.44923480855144826
# Leighton-Baines -0.4522036034371326
# Luke-Thomas -0.4548902280830785
# Harry-Winks -0.4587591351560429
# Conor-Hourihane -0.46364685678872164
# Sead-Kolasinac -0.4647286050141089
# Ilkay-Gundogan -0.47046706304056646
# Neil-Taylor -0.47062067645100913
# James-Milner -0.4716847594442253
# Oleksandr-Zinchenko -0.5340524092994158
# Timothy-Fosu-Mensah -0.5840521843953741

# %%
rk2idx[385]
# Out:
# 347

# %%
for i, d in enumerate(df_basic['Player']):
    nm = d[d.index('\\')+1:]
    print(nm)
# Out:
# Patrick-van-Aanholt
# Max-Aarons
# Tammy-Abraham
# Che-Adams
# Adrian
# Sergio-Aguero
# Albian-Ajeti
# Nathan-Ake
# Marc-Albrighton
# Toby-Alderweireld
# Trent-Alexander-Arnold
# Alisson
# Dele-Alli
# Miguel-Almiron
# Marcos-Alonso
# Steven-Alzate
# Ibrahim-Amadou
# Felipe-Anderson
# Angelino
# Michail-Antonio
# Stuart-Armstrong
# Kepa-Arrizabalaga
# Christian-Atsu
# Pierre-Emerick-Aubameyang
# Serge-Aurier
# Jordan-Ayew
# Cesar-Azpilicueta
# Eric-Bailly
# Leighton-Baines
# Fabian-Balbuena
# George-Baldock
# Phil-Bardsley
# Ross-Barkley
# Ashley-Barnes
# Harvey-Barnes
# Chris-Basham
# Michy-Batshuayi
# Jan-Bednarek
# Hector-Bellerin
# Ryan-Bennett
# Ryan-Bennett
# Kelechi-Iheanacho
# Danny-Ings
# Alex-Iwobi
# Phil-Jagielka
# Alireza-Jahanbakhsh
# Daniel-James
# Reece-James
# Daryl-Janmaat
# Gabriel-Jesus
# Raul-Jimenez
# Joelinton
# Ben-Johnson
# Curtis-Jones
# Phil-Jones
# Jorginho
# Jota
# Diogo-Jota
# James-Justin
# Christian-Kabasele
# Harry-Kane
# NGolo-Kante
# Moise-Kean
# Michael-Keane
# Naby-Keita
# Lloyd-Kelly
# Martin-Kelly
# Max-Kilman
# Joshua-King
# Timm-Klose
# Jonathan-Kodjia
# Sead-Kolasinac
# Ezri-Konsa
# Cheikhou-Kouyate
# Mateo-Kovacic
# Emil-Krafth
# Tim-Krul
# Alexandre-Lacazette
# Adam-Lallana
# Erik-Lamela
# Tariq-Lamptey
# Henri-Lansbury
# Manuel-Lanzini
# Aymeric-Laporte
# Jamaal-Lascelles
# Valentino-Lazaro
# Moritz-Leitner
# Florian-Lejeune
# Aaron-Lennon
# Bernd-Leno
# Jefferson-Lerma
# Jamal-Lewis
# Victor-Lindelof
# Jesse-Lingard
# Hugo-Lloris
# Giovani-Lo-Celso
# Ruben-Loftus-Cheek
# Kevin-Long
# Shane-Long
# Matthew-Longstaff
# Sean-Longstaff
# Dejan-Lovren
# Matthew-Lowton
# David-Luiz
# Douglas-Luiz
# John-Lundstram
# Alexis-Mac-Allister
# James-Maddison
# Harry-Maguire
# Riyad-Mahrez
# Ainsley-Maitland-Niles
# Sadio-Mane
# Javier-Manquillo
# Solly-March
# Pablo-Mari
# Adrian-Mariappa
# Anthony-Martial
# David-Martin
# Martinelli
# Emiliano-Martinez
# Adam-Masina
# Arthur-Masuaku
# Juan-Mata
# Nemanja-Matic
# Joel-Matip
# Neal-Maupay
# James-McArthur
# Oliver-McBurnie
# Alex-McCarthy
# James-McCarthy
# John-McGinn
# David-McGoldrick
# Michael-McGovern
# Kenny-McLean
# Dwight-McNeil
# Scott-McTominay
# Ben-Mee
# Benjamin-Mendy
# Nampalys-Mendy
# Chris-Mepham
# Max-Meyer
# Luka-Milivojevic
# James-Milner
# Yerry-Mina
# Takumi-Minamino
# Tyrone-Mings
# Tyrick-Mitchell
# Henrikh-Mkhitaryan
# Nacho-Monreal
# Martin-Montoya
# Simon-Moore
# Aaron-Mooy
# Wesley-Moraes
# Wes-Morgan
# Mason-Mount
# Lucas-Moura
# Lys-Mousset
# Joao-Moutinho
# Glenn-Murray
# Shkodran-Mustafi
# Yoshinori-Muto
# Marvelous-Nakamba
# Wilfred-Ndidi
# Tanguy-Ndombele
# Reiss-Nelson
# Pedro-Neto
# Ruben-Neves
# Jeremy-Ngakia
# Eddie-Nketiah
# Mark-Noble
# Oliver-Norwood
# Orjan-Nyland
# Jack-OConnell
# Michael-Obafemi
# Angelo-Ogbonna
# Divock-Origi
# Ben-Osborn
# Nicolas-Otamendi
# Alex-Oxlade-Chamberlain
# Mesut-Ozil
# Emerson-Palmieri
# Sokratis-Papastathopoulos
# Rui-Patricio
# Pedro
# Nicolas-Pepe
# Andreas-Pereira
# Ricardo-Pereira
# Roberto-Pereyra
# Ayoze-Perez
# Jordan-Pickford
# Erik-Pieters
# Daniel-Podence
# Paul-Pogba
# Nick-Pope
# Dennis-Praet
# Davy-Propper
# Teemu-Pukki
# Christian-Pulisic
# Aaron-Ramsdale
# Darren-Randolph
# Marcus-Rashford
# Nathan-Redmond
# Pepe-Reina
# Declan-Rice
# Richarlison
# Diego-Rico
# Jairo-Riedewald
# Matt-Ritchie
# Roberto
# Andrew-Robertson
# Callum-Robinson
# Jack-Robinson
# Rodri
# Jay-Rodriguez
# Marcos-Rojo
# Oriol-Romeu
# Danny-Rose
# Danny-Rose
# Antonio-Rudiger
# Lukas-Rupp
# Mathew-Ryan
# Allan-Saint-Maximin
# Romain-Saiss
# Bukayo-Saka
# Mamadou-Sakho
# Mohamed-Salah
# Mbwana-Samatta
# Carlos-Sanchez
# Davinson-Sanchez
# Ismaila-Sarr
# Fabian-Schar
# Ezequiel-Schelotto
# Jeffrey-Schlupp
# Kasper-Schmeichel
# Morgan-Schneiderlin
# Ryan-Sessegnon
# Xherdan-Shaqiri
# Billy-Sharp
# Luke-Shaw
# Jonjo-Shelvey
# Djibril-Sidibe
# Gylfi-Sigurdsson
# Bernardo-Silva
# David-Silva
# Jack-Simpson
# Moussa-Sissoko
# William-Smallbone
# Adam-Smith
# Emile-Smith-Rowe
# Robert-Snodgrass
# Cedric-Soares
# Cedric-Soares
# Dominic-Solanke
# Tomas-Soucek
# Caglar-Soyuncu
# Jack-Stacey
# Junior-Stanislas
# Dale-Stephens
# Jack-Stephens
# Raheem-Sterling
# Enda-Stevens
# Marco-Stiepermann
# John-Stones
# Ki-Sung-yueng
# Andrew-Surman
# Japhet-Tanganga
# Matt-Targett
# James-Tarkowski
# Charlie-Taylor
# Neil-Taylor
# Alexander-Tettey
# Luke-Thomas
# Youri-Tielemans
# Kieran-Tierney
# James-Tomkins
# Fikayo-Tomori
# Lucas-Torreira
# Cenk-Tosun
# Cenk-Tosun
# Andros-Townsend
# Adama-Traore
# Mark-Travers
# Trezeguet
# Leandro-Trossard
# Tom-Trybull
# Axel-Tuanzebe
# Yan-Valery
# Jesus-Vallejo
# Jamie-Vardy
# Jan-Vertonghen
# Jannik-Vestergaard
# Ruben-Vinagre
# Jake-Vokins
# Mario-Vrancic
# Matej-Vydra
# Theo-Walcott
# Kyle-Walker
# Kyle-Walker-Peters
# Kyle-Walker-Peters
# Aaron-Wan-Bissaka
# Joel-Ward
# James-Ward-Prowse
# Adam-Webster
# Danny-Welbeck
# Ashley-Westwood
# Connor-Wickham
# Georginio-Wijnaldum
# Jetro-Willems
# Brandon-Williams
# Neco-Williams
# Willian
# Joe-Willock
# Jack-Wilshere
# Callum-Wilson
# Harry-Wilson
# Harry-Winks
# Chris-Wood
# Granit-Xhaka
# Andriy-Yarmolenko
# DeAndre-Yedlin
# Maya-Yoshida
# Ashley-Young
# Pablo-Zabaleta
# Wilfried-Zaha
# Christoph-Zimmermann
# Oleksandr-Zinchenko
# Richairo-Zivkovic
# Kurt-Zouma
